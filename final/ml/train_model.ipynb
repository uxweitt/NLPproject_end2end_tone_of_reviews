# %%
# %reload_ext autoreload
# %autoreload 2
import model_space as ms
from navec import Navec
import torch
print(torch.__version__)
# Out:
# 2.11.0+cu126

# %%
navec_path = 'navec_hudlit_v1_12B_500K_300d_100q.tar'
navec = Navec.load(navec_path)
rd = ms.ReviewDataset('../../archive/dataset', navec_embedded=navec)
model = ms.ReviewModel(300, 3)
pm = ms.ProcessModel(rd, model, 5, rd.collate_fn, navec_path)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\leva2\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
pm._ds_init(0.8, 0.2)
#pm._train_loop()
#pm._test_loop()
print(pm._inference("Детка ты любишь рваные джинсы"))
print(f"{pm.quality:.3f}")
print(f"{pm.f1_macro:.3f}")
# Out:
# {'class_label': 'neg', 'confidence': 0.711}
# 0.567
# 0.537
